# %% [markdown]
# # Scraping Youtube Comments

# %%
import googleapiclient.discovery
import googleapiclient.errors

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyD4ewMWP_BoxjLTG_zgMbRlycPvYs7vaZs"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="SwSbnmqk3zY",
    maxResults=100
)
response = request.execute()

for item in response['items']:
    print(item['snippet']['topLevelComment']['snippet']['textDisplay'])
# Out:
# Thank you so much for this stuff.
# Project link not working!
# <br> &#39;pageInfo&#39;: {&#39;totalResults&#39;: 0, &#39;resultsPerPage&#39;: 5}} i get only this out from json formatter. TechTFQ can i continue the project? i think i might will be missing most of the important stuff
# for a non-tech background like me, your tutorial is super easy to follow.
# Why the Json is not showing &#39;Likes&#39; ?
# top !
# Hello. i want to ask, how to receive video data (mp4) from youtube?
# can we get also the published time ?
# <a href="https://www.youtube.com/watch?v=SwSbnmqk3zY&amp;t=3285">54:45</a> in my scrapping I didint have snippet , title name and likes and views.. In this only showing video I&#39;d and piblished date. 🥲🥲🥲😐 please any one help me.. Tomorrow I have interview
# ...

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyD4ewMWP_BoxjLTG_zgMbRlycPvYs7vaZs"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="SwSbnmqk3zY",
    maxResults=100
)
response = request.execute()

comments = []

for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['updatedAt'],
        comment['likeCount'],
        comment['textDisplay']
    ])

df = pd.DataFrame(comments, columns=['author', 'published_at', 'updated_at', 'like_count', 'text'])

df.head(10)
# Out:
#                    author          published_at            updated_at  \
# 0        @rahulrajeev9763  2024-04-27T20:24:34Z  2024-04-27T20:24:34Z
# 1          @mohdsaqib3241  2024-04-27T03:46:50Z  2024-04-27T03:46:50Z
# 2         @yankoshuan6225  2024-04-20T19:11:25Z  2024-04-20T19:11:25Z
# 3        @user-uv5lr7bk8n  2024-04-18T02:51:14Z  2024-04-18T02:51:14Z
# 4             @najam00717  2024-04-01T13:19:56Z  2024-04-01T13:19:56Z
# 5              @Abutturab  2024-03-28T08:51:09Z  2024-03-28T08:51:09Z
# 6              @ryang8192  2024-03-21T04:15:06Z  2024-03-21T04:15:06Z
# 7  @DuniaDalamKabarBerita  2024-03-05T01:30:16Z  2024-03-05T01:30:16Z
# 8       @VARUNKUMAR-dj6mi  2024-03-04T09:34:34Z  2024-03-04T09:34:34Z
# 9       @VARUNKUMAR-dj6mi  2024-03-04T09:34:25Z  2024-03-04T09:34:25Z
#
#    like_count                                               text
# 0           0                  Thank you so much for this stuff.
# 1           0                          Project link not working!
# ...

# %%
data3=df.drop(['author','published_at','updated_at','like_count'],axis=1)

data3
# Out:
#                                               Comment
# 0                   Thank you so much for this stuff.
# 1                           Project link not working!
# 2   {&#39;kind&#39;: &#39;youtube<a href="http://w...
# 3   for a non-tech background like me, your tutori...
# 4       Why the Json is not showing &#39;Likes&#39; ?
# ..                                                ...
# 95  I&#39;m getting this error<br><br>  KeyError: ...
# 96                          Absolutely amazing video!
# 97  hi, i am about <a href="https://www.youtube.co...
# 98                      Love this easy to follow 👍🏻👍🏻
# 99  I&#39;m only 25 minutes in and I&#39;ve learne...
#
# [100 rows x 1 columns]

# %% [markdown]
# # Data Loading

# %%
import numpy as np
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import nltk
nltk.download("popular")
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# ...

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/comments.csv')
data.columns
data1=data.drop(['Unnamed: 0','Likes','Time','user','UserLink'],axis=1)
data1
# Out:
#                                                Comment
# 0    Love how Dr. Fate's design looks and how cool ...
# 1    I can’t get over how good everything looks. Dr...
# 2    Really hoping that this can save DC's movie un...
# 3    U cant deny how good this looks.Now if they ca...
# 4    From this trailer, I have a feeling that this ...
# ..                                                 ...
# 275  I want to see this. It may be one of his most ...
# 276       wow thats very amazing. I can't wait to see.
# 277                    Doctor Fate is why i'm watching
# 278  This looks fire. DC looks like they stepping t...
# 279  Shazam : "I don't want fight you Black Adam."B...
#
# [280 rows x 1 columns]

# %% [markdown]
# # Data Transformation

# %% [markdown]
# ### Importing Libraries

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# Import functions for data preprocessing & data preparation
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import resample
from sklearn.feature_extraction.text import CountVectorizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer

from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer, LancasterStemmer
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import stopwords
from nltk.corpus import wordnet
import string
from string import punctuation
import nltk
import re

# %% [markdown]
# ### Data Labelling

# %%
nltk.download('vader_lexicon')
sentiments = SentimentIntensityAnalyzer()
data3["Positive"] = [sentiments.polarity_scores(i)["pos"] for i in data3["Comment"]]
data3["Negative"] = [sentiments.polarity_scores(i)["neg"] for i in data3["Comment"]]
data3["Neutral"] = [sentiments.polarity_scores(i)["neu"] for i in data3["Comment"]]
data3['Compound'] = [sentiments.polarity_scores(i)["compound"] for i in data3["Comment"]]
score = data3["Compound"].values
sentiment = []
for i in score:
    if i >= 0.05 :
        sentiment.append('Positive')
    elif i <= -0.05 :
        sentiment.append('Negative')
    else:
        sentiment.append('Neutral')
data3["Sentiment"] = sentiment
data3.head()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
#                                              Comment  Positive  Negative  \
# 0                  Thank you so much for this stuff.     0.294      0.00
# 1                          Project link not working!     0.000      0.00
# 2  {&#39;kind&#39;: &#39;youtube<a href="http://w...     0.056      0.07
# 3  for a non-tech background like me, your tutori...     0.508      0.00
# 4      Why the Json is not showing &#39;Likes&#39; ?     0.000      0.00
#
#    Neutral  Compound Sentiment
# 0    0.706    0.3612  Positive
# 1    1.000    0.0000   Neutral
# 2    0.874   -0.1271  Negative
# 3    0.492    0.8519  Positive
# 4    1.000    0.0000   Neutral

# %% [markdown]
# ### Final Data

# %%
data2=data3.drop(['Positive','Negative','Neutral','Compound'],axis=1)
data2.head()
# Out:
#                                              Comment Sentiment
# 0                  Thank you so much for this stuff.  Positive
# 1                          Project link not working!   Neutral
# 2  {&#39;kind&#39;: &#39;youtube<a href="http://w...  Negative
# 3  for a non-tech background like me, your tutori...  Positive
# 4      Why the Json is not showing &#39;Likes&#39; ?   Neutral

# %%
stop_words = stopwords.words('english')
porter_stemmer = PorterStemmer()
lancaster_stemmer = LancasterStemmer()
snowball_stemer = SnowballStemmer(language="english")
lzr = WordNetLemmatizer()

# %%
def text_processing(text):
    # convert text into lowercase
    text = text.lower()

    # remove new line characters in text
    text = re.sub(r'\n',' ', text)

    # remove punctuations from text
    text = re.sub('[%s]' % re.escape(punctuation), "", text)

    # remove references and hashtags from text
    text = re.sub("^a-zA-Z0-9$,.", "", text)

    # remove multiple spaces from text
    text = re.sub(r'\s+', ' ', text, flags=re.I)

    # remove special characters from text
    text = re.sub(r'\W', ' ', text)

    text = ' '.join([word for word in word_tokenize(text) if word not in stop_words])


    # lemmatizer using WordNetLemmatizer from nltk package
    text=' '.join([lzr.lemmatize(word) for word in word_tokenize(text)])

    return text

# %%
nltk.download('omw-1.4')
data_copy = data2.copy()
data_copy.Comment = data_copy.Comment.apply(lambda text: text_processing(text))
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
le = LabelEncoder()
data_copy['Sentiment'] = le.fit_transform(data_copy['Sentiment'])

# %%
processed_data = {
    'Sentence':data_copy.Comment,
    'Sentiment':data_copy['Sentiment']
}

processed_data = pd.DataFrame(processed_data)
processed_data.head()
# Out:
#                                             Sentence  Sentiment
# 0                                   thank much stuff          2
# 1                               project link working          1
# 2  39kind39 39youtubea hrefhttpwwwyoutubecomresul...          0
# 3  nontech background like tutorial super easy fo...          2
# 4                             json showing 39likes39          1

# %%
processed_data['Sentiment'].value_counts()
# Out:
# Sentiment
# 2    59
# 1    27
# 0    14
# Name: count, dtype: int64

# %% [markdown]
# Balacing Data

# %%
df_neutral = processed_data[(processed_data['Sentiment']==1)]
df_negative = processed_data[(processed_data['Sentiment']==0)]
df_positive = processed_data[(processed_data['Sentiment']==2)]

# upsample minority classes
df_negative_upsampled = resample(df_negative,
                                 replace=True,
                                 n_samples= 205,
                                 random_state=42)

df_neutral_upsampled = resample(df_neutral,
                                 replace=True,
                                 n_samples= 205,
                                 random_state=42)

df_neutral_upsampled = resample(df_positive,
                                 replace=True,
                                 n_samples= 205,
                                 random_state=42)


# Concatenate the upsampled dataframes with the neutral dataframe
final_data = pd.concat([df_negative_upsampled,df_neutral_upsampled,df_positive_unsampled])

# %%
final_data['Sentiment'].value_counts()
# Out:
# Sentiment
# 0    205
# 1    205
# 2     59
# Name: count, dtype: int64

# %%
corpus = []
for sentence in final_data['Sentence']:
    corpus.append(sentence)
corpus[0:5]
# Out:
# ['brtypeerror traceback recent call last brcell in38 line 3 br 1 apikey 39aizasybjdhkefud2tu0gauz34bhwzzslyuq2r8g39 br 2 channelid 39ienetworks217039 brgt 3 youtube build39youtube39 39v339 developerkeyapikey br brtypeerror 39module39 object callablebrbrbr fix problem',
#  'module named googleapiclient error solve error sir',
#  'hello i39m trying run code get video detail list videoids ssl error running videodetailsgetvideodetailsyoutube videoids don39t know fix error following quotsslcertverificationerror ssl certificateverifyfailed certificate verify failed self signed certificate certificate chain sslc1129quot know fix thanks',
#  'pycharm i39m unable get return response code executed perfectly output console',
#  'seeing project 2023 function get video id remove dislike code youtube api give information dislike']

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=1500)
X = cv.fit_transform(corpus).toarray()
y = final_data.iloc[:, -1].values

# %% [markdown]
# # ML Model

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
y_pred = classifier.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[65,  0,  0],
#        [ 0, 62,  0],
#        [ 1,  2, 11]])

# %%
nb_score = accuracy_score(y_test, y_pred)
print('accuracy',nb_score)
# Out:
# accuracy 0.9787234042553191
